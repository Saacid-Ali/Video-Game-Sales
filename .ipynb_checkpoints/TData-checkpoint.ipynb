# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

# %%
data = pd.read_csv('VGSales.csv', encoding='latin1')
TS = pd.DataFrame(data)

# %%
TS.drop(['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales'], axis=1)
# Out:
#                                            Name Platform  Year_of_Release  \
# 0                            Grand Theft Auto V      PS4             2014
# 1                     Call of Duty: Black Ops 3      PS4             2015
# 2                            Call of Duty: WWII      PS4             2017
# 3                                       FIFA 18      PS4             2017
# 4                                       FIFA 17      PS4             2016
# ...                                         ...      ...              ...
# 1070                   Deception IV: Blood Ties      PS4             2015
# 1071                                Raven's Cry      PS4             2015
# 1072                        Rugby League Live 3     XOne             2015
# 1073                                  Teslagrad      PS4             2014
# 1074  Rabbids Invasion: The Interactive TV Show     XOne             2014
#
#              Genre              Publisher  Global_Sales
# 0           Action         Rockstar Games         19.39
# 1          Shooter             Activision         15.09
# 2          Shooter             Activision         13.40
# 3           Sports              EA Sports         11.80
# 4           Sports        Electronic Arts         10.94
# ...            ...                    ...           ...
# 1070        Action             Tecmo Koei          0.01
# 1071  Role-Playing    TopWare Interactive          0.01
# 1072        Sports  Tru Blu Entertainment          0.01
# 1073      Platform             Rain Games          0.01
# 1074          Misc                Ubisoft          0.01
#
# [1075 rows x 6 columns]
